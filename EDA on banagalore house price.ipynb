# %% [markdown]
# importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the Dataset

# %%
data = pd.read_csv("bangalore house price prediction OHE-data.csv")
data
# Out:
#       bath  balcony   price  total_sqft_int  bhk  price_per_sqft  \
# 0      3.0      2.0  150.00          1672.0    3     8971.291866
# 1      3.0      3.0  149.00          1750.0    3     8514.285714
# 2      3.0      2.0  150.00          1750.0    3     8571.428571
# 3      2.0      2.0   40.00          1250.0    2     3200.000000
# 4      2.0      2.0   83.00          1200.0    2     6916.666667
# ...    ...      ...     ...             ...  ...             ...
# 7115   3.0      2.0  325.00          2900.0    3    11206.896552
# 7116   3.0      1.0   84.83          1780.0    3     4765.730337
# 7117   2.0      1.0   48.00           880.0    2     5454.545455
# 7118   2.0      1.0   55.00          1000.0    2     5500.000000
# 7119   2.0      1.0   78.00          1400.0    3     5571.428571
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                                 1                        0
# ...

# %% [markdown]
# Number of rows & columns

# %%
data.shape
# Out:
# (7120, 108)

# %%
data.describe()
# Out:
#               bath      balcony        price  total_sqft_int          bhk  \
# count  7120.000000  7120.000000  7120.000000     7120.000000  7120.000000
# mean      2.390871     1.572759    96.454991     1479.729806     2.465169
# std       0.876822     0.770583   116.185034      913.779769     0.841520
# min       1.000000     0.000000    10.000000      350.000000     1.000000
# 25%       2.000000     1.000000    49.230000     1100.000000     2.000000
# 50%       2.000000     2.000000    69.000000     1255.000000     2.000000
# 75%       3.000000     2.000000   104.000000     1640.250000     3.000000
# max       9.000000     3.000000  2912.000000    30400.000000     9.000000
#
#        price_per_sqft  area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# count     7120.000000                    7120.000000              7120.000000
# mean      5923.806855                       0.750702                 0.182303
# ...

# %% [markdown]
# Exploratory Data Analysis

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7120 entries, 0 to 7119
# Columns: 108 entries, bath to location_Tumkur Road
# dtypes: float64(5), int64(103)
# memory usage: 5.9 MB
# None

# %%
print(data.isnull().sum())
# Out:
# bath                           0
# balcony                        0
# price                          0
# total_sqft_int                 0
# bhk                            0
#                               ..
# location_Hosur Road            0
# location_Horamavu Banaswadi    0
# location_Domlur                0
# location_Mahadevpura           0
# location_Tumkur Road           0
# Length: 108, dtype: int64

# %%
print(data["bath"].unique())
# Out:
# [3. 2. 1. 4. 5. 9. 6. 8. 7.]

# %%
print(data["balcony"].unique())
# Out:
# [2.         3.         1.         0.         1.58437574]

# %% [markdown]
# We can see that there are houses with 1.58437574 balconies which appears unusual.

# %%
data[(data["balcony"]>1.1) & (data["balcony"]<1.7)]
# Out:
#       bath   balcony    price  total_sqft_int  bhk  price_per_sqft  \
# 48     2.0  1.584376    86.00          1200.0    2     7166.666667
# 87     9.0  1.584376   500.00          4500.0    9    11111.111111
# 93     4.0  1.584376   333.00          3900.0    4     8538.461538
# 108    5.0  1.584376   110.00          2500.0    5     4400.000000
# 127    4.0  1.584376   250.00          3245.0    4     7704.160247
# ...    ...       ...      ...             ...  ...             ...
# 7074   2.0  1.584376    46.17          1200.0    2     3847.500000
# 7077   9.0  1.584376  1900.00         12000.0    8    15833.333333
# 7080   5.0  1.584376  1950.00         10000.0    5    19500.000000
# 7093   5.0  1.584376   220.00          3600.0    4     6111.111111
# 7114   6.0  1.584376   390.00          3800.0    6    10263.157895
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 48                                1                        0
# ...

# %%
(202/7120)*100
# Out:
# 2.837078651685393

# %% [markdown]
# we can see there are around 202 records with 1.584376 no of balconies.This 202 records occupy around 2.8 percent of our data. We have total 7120 records,so lets drop this rows with errors.

# %%
df = data[(data["balcony"]==0)|(data["balcony"]==1)|(data["balcony"]==2)|(data["balcony"]==3)]

# %%
df.head()
# Out:
#    bath  balcony  price  total_sqft_int  bhk  price_per_sqft  \
# 0   3.0      2.0  150.0          1672.0    3     8971.291866
# 1   3.0      3.0  149.0          1750.0    3     8514.285714
# 2   3.0      2.0  150.0          1750.0    3     8571.428571
# 3   2.0      2.0   40.0          1250.0    2     3200.000000
# 4   2.0      2.0   83.0          1200.0    2     6916.666667
#
#    area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                              1                        0
# 1                              0                        1
# 2                              1                        0
# 3                              1                        0
# 4                              0                        0
#
#    area_typePlot  Area  availability_Ready To Move  ...  \
# 0                    0                           1  ...
# 1                    0                           1  ...
# 2                    0                           1  ...
# ...

# %%
print("Total no. Houses are ---", len(df))
print("Houses with Super built-up Area--",len(df[df['area_typeSuper built-up  Area']==1]))
print("Houses with Built-up Area--",len(df[df['area_typeBuilt-up  Area']==1]))
print("Houses with plot Area--",len(df[df['area_typePlot  Area']==1]))
print("--------------")
print("Upto {} BHK Houses are Avialabels---".format(df["bhk"].max()))
print("Total no. of Availibity to move--",len(df[df['availability_Ready To Move']==1]))
print("--------------")
print("Average price per sqt---",df["price_per_sqft"].mean())
# Out:
# Total no. Houses are --- 6918
# Houses with Super built-up Area-- 5212
# Houses with Built-up Area-- 1257
# Houses with plot Area-- 417
# --------------
# Upto 9 BHK Houses are Avialabels---
# Total no. of Availibity to move-- 5465
# --------------
# Average price per sqt--- 5868.9193989551

# %%
plt.figure(figsize=(6,3))
sns.barplot(x=df["bhk"],y=df["price_per_sqft"],data=df)
plt.title("size of bhk V/S price of per square fit area")
# Out:
# Text(0.5, 1.0, 'size of bhk V/S price of per square fit area')

# %%
sns.countplot(x=df["bhk"],data=df)
plt.title("count of bhk")
# Out:
# Text(0.5, 1.0, 'count of bhk')

# %%
sns.barplot(x=df["bath"],y=df["price_per_sqft"],data=df)
# Out:
# <Axes: xlabel='bath', ylabel='price_per_sqft'>

# %%
sns.lineplot(x=df["bhk"],y=df["price_per_sqft"],data=df)
# Out:
# <Axes: xlabel='bhk', ylabel='price_per_sqft'>

# %%
sns.lineplot(x=df["bath"],y=df["price_per_sqft"],data=df)
# Out:
# <Axes: xlabel='bath', ylabel='price_per_sqft'>

# %%
plt.figure(figsize=(20,18))
plt.subplot(5,5,1)
sns.barplot(x=df["bath"],data=df)
plt.subplot(5,5,2)
sns.barplot(x=df["bhk"],data=df)
plt.subplot(5,5,3)
sns.barplot(x=df["balcony"],data=df)
plt.subplot(5,5,4)
sns.barplot(x=df["price"],data=df)
plt.subplot(5,5,5)
sns.barplot(x=df["total_sqft_int"],data=df)
plt.subplot(5,5,6)
sns.barplot(x=df["price_per_sqft"],data=df)
plt.subplot(5,5,7)
sns.barplot(x=df["area_typeSuper built-up  Area"],data=df)
plt.subplot(5,5,8)
sns.barplot(x=df["area_typeBuilt-up  Area"],data=df)
plt.subplot(5,5,9)
sns.barplot(x=df["area_typePlot  Area"],data=df)
plt.subplot(5,5,10)
sns.barplot(x=df["availability_Ready To Move"],data=df)
plt.subplot(5,5,11)
sns.barplot(x=df["location_Kalena Agrahara"],data=df)
plt.subplot(5,5,12)
sns.barplot(x=df["location_Horamavu Agara"],data=df)
plt.subplot(5,5,13)
sns.barplot(x=df["location_Vidyaranyapura"],data=df)
plt.subplot(5,5,13)
sns.barplot(x=df["location_BTM 2nd Stage"],data=df)
plt.subplot(5,5,14)
sns.barplot(x=df["location_Hebbal Kempapura"],data=df)
plt.subplot(5,5,15)
sns.barplot(x=df["location_Hosur Road"],data=df)
plt.subplot(5,5,16)
sns.barplot(x=df["location_Horamavu Banaswadi"],data=df)
plt.subplot(5,5,17)
sns.barplot(x=df["location_Domlur"],data=df)
plt.subplot(5,5,18)
sns.barplot(x=df["location_Mahadevpura"],data=df)
plt.subplot(5,5,19)
sns.barplot(x=df["location_Tumkur Road"],data=df)
# Out:
# <Axes: xlabel='location_Tumkur Road'>

# %% [markdown]
# Corelations betweeen columns

# %%
df[["bath","bhk","balcony","price","total_sqft_int","price_per_sqft","area_typeSuper built-up  Area","area_typeBuilt-up  Area","area_typePlot  Area","availability_Ready To Move"]].corr()
# Out:
#                                    bath       bhk   balcony     price  \
# bath                           1.000000  0.875053  0.300074  0.510338
# bhk                            0.875053  1.000000  0.284045  0.488212
# balcony                        0.300074  0.284045  1.000000  0.154844
# price                          0.510338  0.488212  0.154844  1.000000
# total_sqft_int                 0.676229  0.674932  0.233158  0.777053
# price_per_sqft                 0.335517  0.312623  0.070028  0.734374
# area_typeSuper built-up  Area -0.111749 -0.134302  0.122504 -0.109201
# area_typeBuilt-up  Area        0.031170  0.043292 -0.049171 -0.012394
# area_typePlot  Area            0.152927  0.170791 -0.142729  0.221210
# availability_Ready To Move     0.016270  0.038208  0.118364  0.012499
#
#                                total_sqft_int  price_per_sqft  \
# bath                                 0.676229        0.335517
# bhk                                  0.674932        0.312623
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df[["bath","bhk","balcony","price","total_sqft_int","price_per_sqft","area_typeSuper built-up  Area","area_typeBuilt-up  Area","area_typePlot  Area","availability_Ready To Move"]].corr(),annot=True)
# Out:
# <Axes: >
